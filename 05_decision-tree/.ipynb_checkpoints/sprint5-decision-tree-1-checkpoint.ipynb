# %% [markdown]
# # タイタニック生存予測 ランダムフォレスト
#
# ランダムフォレストを用いて、生存を予測することを目指す。
#
# - 問題提起
# - データ取得
# - データ可視化
# - 前処理
# - モデル選択
# - データセット分割
# - 学習
# - 評価

# %% [markdown]
# ## 問題定義
# ランダムフォレストを用いて、生存を予測することを目指す。
#
#
# ## データ取得

# %%
# 必要なモジュールを用意します。
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train = pd.read_csv('input/train.csv')
df_test = pd.read_csv('input/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train["Cabin"].value_counts()
# Out:
# G6             4
# B96 B98        4
# C23 C25 C27    4
# D              3
# F33            3
# E101           3
# C22 C26        3
# F2             3
# B5             2
# B22            2
# D26            2
# B35            2
# C68            2
# B49            2
# D17            2
# B20            2
# B51 B53 B55    2
# D35            2
# C123           2
# C92            2
# C2             2
# E25            2
# D36            2
# C93            2
# E67            2
# F4             2
# E33            2
# B28            2
# C125           2
# E44            2
#               ..
# A36            1
# C45            1
# D19            1
# E68            1
# A20            1
# D7             1
# C54            1
# D30            1
# B101           1
# B19            1
# A7             1
# D48            1
# B37            1
# E50            1
# C87            1
# D11            1
# B50            1
# C50            1
# A14            1
# F E69          1
# A10            1
# A26            1
# B79            1
# F G63          1
# C30            1
# C110           1
# C148           1
# C32            1
# A5             1
# D37            1
# Name: Cabin, Length: 147, dtype: int64

# %%
# df.sample
# n：件数分取得
# frac：10%取得
df_train.sample(n=5)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 174          175         0       1                Smith, Mr. James Clinch
# 81            82         1       3            Sheerlinck, Mr. Jan Baptist
# 437          438         1       2  Richards, Mrs. Sidney (Emily Hocking)
# 855          856         1       3             Aks, Mrs. Sam (Leah Rosen)
# 7              8         0       3         Palsson, Master. Gosta Leonard
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 174    male  56.0      0      0   17764  30.6958    A7        C
# 81     male  29.0      0      0  345779   9.5000   NaN        S
# 437  female  24.0      2      3   29106  18.7500   NaN        S
# 855  female  18.0      0      1  392091   9.3500   NaN        S
# 7      male   2.0      3      1  349909  21.0750   NaN        S

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# ## 前処理について
# - 前処理とは何か
# - なぜ前処理を行う必要があるのか
# - 前処理は具体的に何を行うか（3つ以上記述せよ）
# - 前述した具体的な前処理について、その前処理を行うと何を得ることができるか（記述したそれぞれの前処理例について記述せよ）

# %% [markdown]
# 前処理とは、機械学習アルゴリズムで構築されたモデルでの**分析を正常に稼働させる**ため、取得データを**各値の関係性を損ねることなく加工**する作業。
# 具体的には、
#
# **欠損値補完**
# 取得データにnull値があると、モデルにデータが渡せないので、最適な数値に変換する必要がある。(カテゴリカルの場合は、適当な文字列に変換)
# - データ数が多く、欠損値のあるデータが限りなく少ない場合、データごと削除（**リストワイズ法**）
# - 値がランダムに欠損しているということが確認できている場合、カラムの平均を欠損値に代入（**平均代入法**）
# - 上記いずれにも該当しない場合、連鎖方程式(MICE)による多重代入法で、欠損値を補完
#
# **カテゴリカルデータのエンコーディング（数値化）**
# 取得データにカテゴリカル値があると、モデルにデータが渡せないので、最適な数値に変換する必要がある。
# - カテゴリカル値が尺度や順位を意味している場合、各分類を数値に変換
# - カテゴリカル値が名義である場合、カテゴリカル値の分類数分のカラムを増やし、バイナリ真理値（one-hot表現）に変換
#
# **スケーリング**
# 範囲の大きい特徴量に影響を受けすぎることによる過学習を防ぐため、数的関係を損ねることなく、数値の範囲を統一させる必要がある。
# - データに外れ値がなく、一様分布の場合、0〜１の範囲に正規化させる。
# - 上記以外の場合、平均が0、標準偏差が１に標準化させる。

# %% [markdown]
# ### 上記、前処理についての調査により、データを確認する際にどのような点を見るとよいか、3つ以上記述せよ。

# %% [markdown]
# - 欠損値の有無を確認。データ数が多く、欠損値データが限りなく少ない場合はデータ削除。でなければ、欠損値に数値を補完。
# - データのタイプを確認。カテゴリカルデータが見つかれば、エンコーディングを実施。
# - データをプロットし、外れ値の有無を確認。外れ値がある場合、標準化でスケール変換させる。

# %% [markdown]
# ## 前処理を行う

# %%
def simplify_ages(df):
    df.Age = df.Age.fillna(-0.5)
    bins = (-1, 0, 5, 12, 18, 25, 35, 60, 120)
    group_names = ['Unknown', 'Baby', 'Child', 'Teenager', 'Student', 'Young Adult', 'Adult', 'Senior']
    categories = pd.cut(df.Age, bins, labels=group_names)
    df.Age = categories
    return df

def simplify_cabins(df):
    df.Cabin = df.Cabin.fillna('N')
    df.Cabin = df.Cabin.apply(lambda x: x[0])
    return df

def simplify_fares(df):
    df.Fare = df.Fare.fillna(-0.5)
    bins = (-1, 0, 8, 15, 31, 1000)
    group_names = ['Unknown', '1_quartile', '2_quartile', '3_quartile', '4_quartile']
    categories = pd.cut(df.Fare, bins, labels=group_names)
    df.Fare = categories
    return df

def format_name(df):
    df['Lname'] = df.Name.apply(lambda x: x.split(' ')[0])
    df['NamePrefix'] = df.Name.apply(lambda x: x.split(' ')[1])
    return df

def drop_features(df):
    return df.drop(['Ticket', 'Name', 'Embarked'], axis=1)

def transform_features(df):
    df = simplify_ages(df)
    df = simplify_cabins(df)
    df = simplify_fares(df)
    df = format_name(df)
    df = drop_features(df)
    return df

data_train = transform_features(df_train)
data_test = transform_features(df_test)
data_train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex          Age  SibSp  Parch  \
# 0            1         0       3    male      Student      1      0
# 1            2         1       1  female        Adult      1      0
# 2            3         1       3  female  Young Adult      0      0
# 3            4         1       1  female  Young Adult      1      0
# 4            5         0       3    male  Young Adult      0      0
#
#          Fare Cabin       Lname NamePrefix
# 0  1_quartile     N     Braund,        Mr.
# 1  4_quartile     C    Cumings,       Mrs.
# 2  1_quartile     N  Heikkinen,      Miss.
# 3  4_quartile     C   Futrelle,       Mrs.
# 4  2_quartile     N      Allen,        Mr.

# %%
data_test.head()
# Out:
#    PassengerId  Pclass     Sex          Age  SibSp  Parch        Fare Cabin  \
# 0          892       3    male  Young Adult      0      0  1_quartile     N
# 1          893       3  female        Adult      1      0  1_quartile     N
# 2          894       2    male       Senior      0      0  2_quartile     N
# 3          895       3    male  Young Adult      0      0  2_quartile     N
# 4          896       3  female      Student      1      1  2_quartile     N
#
#        Lname NamePrefix
# 0     Kelly,        Mr.
# 1    Wilkes,       Mrs.
# 2     Myles,        Mr.
# 3      Wirz,        Mr.
# 4  Hirvonen,       Mrs.

# %%
from sklearn import preprocessing
def encode_features(df_train, df_test):
    features = ['Fare', 'Cabin', 'Age', 'Sex', 'Lname', 'NamePrefix']
    df_combined = pd.concat([df_train[features], df_test[features]])

    for feature in features:
        le = preprocessing.LabelEncoder()
        le = le.fit(df_combined[feature])
        df_train[feature] = le.transform(df_train[feature])
        df_test[feature] = le.transform(df_test[feature])
    return df_train, df_test

data_train, data_test = encode_features(data_train, data_test)
data_train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch  Fare  Cabin  Lname  \
# 0            1         0       3    1    4      1      0     0      7    100
# 1            2         1       1    0    0      1      0     3      2    182
# 2            3         1       3    0    7      0      0     0      7    329
# 3            4         1       1    0    7      1      0     3      2    267
# 4            5         0       3    1    7      0      0     1      7     15
#
#    NamePrefix
# 0          19
# 1          20
# 2          16
# 3          20
# 4          19

# %%
data_test.head()
# Out:
#    PassengerId  Pclass  Sex  Age  SibSp  Parch  Fare  Cabin  Lname  NamePrefix
# 0          892       3    1    7      0      0     0      7    401          19
# 1          893       3    0    0      1      0     0      7    843          20
# 2          894       2    1    3      0      0     1      7    552          19
# 3          895       3    1    7      0      0     1      7    851          19
# 4          896       3    0    4      1      1     1      7    342          20

# %% [markdown]
# ## 前処理の内容について
# 下記メソッドがそれぞれ何を行っているか記述せよ
# それぞれなぜそのようなことを行っているか記述せよ（それによって得られるメリットまで考察すること）
#
# **simplify_ages**
# 年齢という数値に影響を受けすぎないようにするため、年齢層に変換
#
# **simplify_cabins**
# null値のままでは、モデルにデータを渡せないため、まずカテゴリカルの欠損値を文字列に変換
#
#
#
# - simplify_fares
# - format_name
# - drop_features
# - encode_features

# %% [markdown]
# ## モデル選択について

# %% [markdown]
# - 今回は、生存予測（分類）を行いますが、この分類について使用できそうな手法を4つ以上しらべて記述せよ。
# - その手法の概要をそれぞれ記述せよ
# - その手法の長所/短所をそれぞれ3つずつ、記述したすべての手法において記述せよ

# %% [markdown]
# ## モデル選択の基準
# 下記の参考資料を元に、どのような視点からモデルを選択すれば良いか、最低でも3つ以上の視点を記述すること（他の参考資料でも構わない、その場合参考資料を明記すること）
#
# https://docs.microsoft.com/ja-jp/azure/machine-learning/machine-learning-algorithm-choice
# https://datumstudio.jp/blog/

# %% [markdown]
# ## モデル選択におけるデータ可視化
# モデルを選択する際にデータ可視化を行い、データの特徴を把握した上で、モデルを選択することができます。

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.barplot(x="Age", y="Survived", hue="Sex", data=data_train);

# %%
sns.pointplot(x="Pclass", y="Survived", hue="Sex", data=data_train,
              palette={1: "blue", 0: "pink"},
              markers=["*", "o"], linestyles=["-", "--"]);

# %% [markdown]
# ## データ可視化の結果について考察
# - 上記の２つの可視化から分かったことについて考察せよ。
# - 上記の考察結果から、モデル選択を考える場合、どのようなことが考えられるか

# %%
# 回答

# %% [markdown]
# ## データセットの分割
# 学習データとテストデータの比は8:2とします。

# %%
from sklearn.model_selection import train_test_split

X = data_train.drop(['Survived', 'PassengerId'], axis=1)
y = data_train['Survived']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=0)

# %% [markdown]
# ## ランダムフォレストについて
#
# - 決定木とはどのような手法か
# - ランダムフォレストとはどのような手法か
# - ランダムフォレストの長所と短所をそれぞれ3つ以上挙げてください。
# - 今回の目的からランダムフォレストの手法が適する理由を考察し、記述せよ
#
# ※決定木とランダムフォレストについては、前述のモデル選択について記述せよにおいて記述していた場合、同じものを記述しても構いません。
#
# - ロジスティック回帰
# - K近傍法
# - サポートベクターマシン
# - ナイーブベイズ分類
# - 決定木
# - ランダムフォレスト
# - パーセプトロン
# - 人工ニューラルネットワーク
# - 関連ベクターマシン
#
# つぎにデータを用意します。

# %% [markdown]
# ## 学習
# ランダムフォレストを使用して、学習
#
# http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=15,criterion='entropy', random_state=0)
clf.fit(X_train, y_train)

print(clf.score(X_train, y_train))
print(clf.score(X_test, y_test))
# Out:
# 0.9705056179775281
# 0.8044692737430168

# %%
# from sklearn import tree

# tree_clf = tree.DecisionTreeClassifier(max_depth=15, criterion='entropy',random_state=0)
# tree_clf.fit(X_train,y_train)

# print(tree_clf.score(X_train, y_train))
# print(tree_clf.score(X_test, y_test))

# %% [markdown]
# ## accuracy

# %%
y_pred=clf.predict(X_test)

from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8044692737430168

# %% [markdown]
# ## ハイパーパラメータについて
# - ハイパーパラメーターとは何か
# - ランダムフォレストにおいてどのようなハイパーパラメーターがあるか4つ以上記述せよ
# - 記述したハイパーパラメーターにおいて、それぞれどのような値が存在するか記述せよ（そのハイパーパラメーターを変化させるとどのようなことが起きるかも記述すること）
#
# http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html

# %% [markdown]
# ハイパーパラメータとは、機械学習アルゴリズムが学習を行う際に、人間が予め設定しなければならないパラメータのことであり、モデルの精度に関わる。
#
# 'n_estimators': [4, 6, 9],
# 'max_features': ['log2', 'sqrt','auto'],
# 'criterion': ['entropy', 'gini'],
# 'max_depth': [2, 3, 5, 10],
# 'min_samples_split': [2, 3, 5],
# 'min_samples_leaf': [1,5,8]

# %% [markdown]
# ## チューニング
# 思うような精度が出ていない場合、チューニングを行う必要があります。
# 今回はハイパーパラメーターを変更し、チューニングを行いましょう。
#
# 以下の観点からチューニングを複数行い、精度の向上を目指します。
# それぞれのハイパーパラメーターの例を示しています。’n_estimators’であれば、4,6,9を試してみましょう。
#
# - グリッドサーチでパラメータチューニングすればよい。
# - 検証一切なしだったので交差検証などを行う
# - ランダムフォレストが特徴量を選んでくれるので使う特徴量を10個に絞らず、もっと多めにモデルに渡せばよかった。
# - 特徴量エンジニアリング　(いくつかの項目の合計面積など）

# %% [markdown]
# - 'n_estimators': [4, 6, 9],
# - 'max_features': ['log2', 'sqrt','auto'],
# - 'criterion': ['entropy', 'gini'],
# - 'max_depth': [2, 3, 5, 10],
# - 'min_samples_split': [2, 3, 5],
# - 'min_samples_leaf': [1,5,8]

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

tuned_parameters = [{
    'n_estimators': [4, 6, 9],
    'max_features': ['log2', 'sqrt','auto'],
    'criterion': ['entropy', 'gini'],
    'max_depth': [2, 3, 5, 10, 15],
    'min_samples_split': [2, 3, 5],
    'min_samples_leaf': [1,5,8]
}]


clf = GridSearchCV(RandomForestClassifier(), #識別器
                   tuned_parameters, #最適化したいパラメータセット
                   scoring= 'accuracy',
                   cv=None, # 交差検証の回数
                   )

#clf = RandomForestClassifier(max_depth=15,criterion='entropy', random_state=0)
clf.fit(X_train, y_train)
# Out:
# /Users/enomoto/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/enomoto/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# GridSearchCV(cv=None, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid=[{'n_estimators': [4, 6, 9], 'max_features': ['log2', 'sqrt', 'auto'], 'criterion': ['entropy', 'gini'], 'max_depth': [2, 3, 5, 10, 15], 'min_samples_split': [2, 3, 5], 'min_samples_leaf': [1, 5, 8]}],
#        pre_dispatch='2*n_jobs', refit=True, scoring='accuracy', verbose=0)

# %%
clf.grid_scores_
# Out:
# [mean: 0.79073, std: 0.01404, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.77669, std: 0.01543, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79635, std: 0.01065, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.76404, std: 0.01570, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.76685, std: 0.01852, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80056, std: 0.01571, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.78652, std: 0.03087, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.77809, std: 0.03074, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.78230, std: 0.01673, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.77388, std: 0.00422, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80337, std: 0.03266, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79635, std: 0.00487, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80758, std: 0.01652, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.76685, std: 0.02359, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.78090, std: 0.01873, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.77809, std: 0.01514, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79073, std: 0.04287, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.78090, std: 0.03544, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.75983, std: 0.04479, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80618, std: 0.02122, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.78371, std: 0.02113, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.77528, std: 0.01276, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.78230, std: 0.02033, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79354, std: 0.02557, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.79775, std: 0.02688, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.76545, std: 0.02914, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.77809, std: 0.02069, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80056, std: 0.04030, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79916, std: 0.00182, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.78652, std: 0.01850, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.77528, std: 0.03148, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80337, std: 0.03079, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79354, std: 0.02371, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.78371, std: 0.02838, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.78511, std: 0.02665, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.79354, std: 0.02687, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.76545, std: 0.04355, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.77809, std: 0.00747, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79354, std: 0.02364, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79073, std: 0.02248, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.76966, std: 0.02886, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.78090, std: 0.02076, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80478, std: 0.03210, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.76264, std: 0.05507, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.79635, std: 0.03067, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.76966, std: 0.03660, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79213, std: 0.02544, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79213, std: 0.02840, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.77247, std: 0.00993, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79775, std: 0.03450, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.78230, std: 0.02923, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.78792, std: 0.01278, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79073, std: 0.02639, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80618, std: 0.01478, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.76124, std: 0.02929, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.78230, std: 0.03036, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.78371, std: 0.04651, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.78230, std: 0.02407, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79354, std: 0.02557, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79213, std: 0.02200, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80478, std: 0.01571, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.78090, std: 0.01534, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.78090, std: 0.01775, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.77669, std: 0.02712, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.78792, std: 0.00817, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.78371, std: 0.01722, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.75843, std: 0.03355, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79635, std: 0.02882, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.77388, std: 0.01402, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.77809, std: 0.02406, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.78652, std: 0.02443, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.76685, std: 0.02056, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.76685, std: 0.02294, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79354, std: 0.02666, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.78230, std: 0.01544, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.75983, std: 0.01678, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79635, std: 0.01348, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.77528, std: 0.02199, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.77388, std: 0.02562, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.78511, std: 0.01874, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.77107, std: 0.02244, params: {'criterion': 'entropy', 'max_depth': 2, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.78371, std: 0.02932, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80478, std: 0.00535, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80618, std: 0.03275, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80197, std: 0.03238, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.81039, std: 0.02109, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80758, std: 0.02073, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.79635, std: 0.01046, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80056, std: 0.01021, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.79916, std: 0.02644, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80197, std: 0.02051, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.81039, std: 0.01878, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79916, std: 0.01405, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.78371, std: 0.01871, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80056, std: 0.02041, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.78652, std: 0.01967, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.77388, std: 0.00352, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79635, std: 0.02187, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80478, std: 0.00489, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.77809, std: 0.01681, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80478, std: 0.02890, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80478, std: 0.01859, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79073, std: 0.02202, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79213, std: 0.02840, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79775, std: 0.02050, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.78511, std: 0.01874, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80056, std: 0.01944, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80337, std: 0.03040, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.78933, std: 0.01571, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79775, std: 0.02121, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80197, std: 0.02956, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79775, std: 0.00577, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80197, std: 0.02936, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79073, std: 0.02034, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80478, std: 0.01600, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.78511, std: 0.00867, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.78230, std: 0.01172, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79775, std: 0.02071, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.81180, std: 0.01587, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80618, std: 0.01539, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79916, std: 0.02204, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79916, std: 0.02446, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79916, std: 0.01261, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.79916, std: 0.02005, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79775, std: 0.02900, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80758, std: 0.02037, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79073, std: 0.01545, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79213, std: 0.02260, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80197, std: 0.02956, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79916, std: 0.01585, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80758, std: 0.01854, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79494, std: 0.03665, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.79213, std: 0.02246, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.81320, std: 0.02512, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.78792, std: 0.02246, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80056, std: 0.04538, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79635, std: 0.01973, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80337, std: 0.00953, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79354, std: 0.02642, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80478, std: 0.02301, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79494, std: 0.02720, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.77528, std: 0.00560, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79916, std: 0.00834, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.79775, std: 0.01458, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79635, std: 0.02040, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79494, std: 0.02493, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79213, std: 0.02400, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80197, std: 0.02644, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80899, std: 0.01023, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80478, std: 0.02742, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.79494, std: 0.02925, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79494, std: 0.01968, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.79635, std: 0.03152, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80056, std: 0.03068, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.78792, std: 0.02509, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79213, std: 0.01122, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79213, std: 0.02200, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80618, std: 0.01202, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79494, std: 0.01405, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80899, std: 0.02890, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.78933, std: 0.01456, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.79916, std: 0.03154, params: {'criterion': 'entropy', 'max_depth': 3, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79635, std: 0.01446, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.81742, std: 0.00692, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.81180, std: 0.01264, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80056, std: 0.00488, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79635, std: 0.02538, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80899, std: 0.00535, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80337, std: 0.00237, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80197, std: 0.01477, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80478, std: 0.02041, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80197, std: 0.01379, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80197, std: 0.01341, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.82163, std: 0.00534, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80899, std: 0.01394, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79354, std: 0.01149, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80758, std: 0.01263, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.81461, std: 0.00656, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80056, std: 0.01349, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80337, std: 0.00182, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79354, std: 0.01476, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79916, std: 0.02446, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79354, std: 0.01149, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80478, std: 0.01393, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79916, std: 0.02005, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80899, std: 0.01657, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.81882, std: 0.01798, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79494, std: 0.02720, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.79916, std: 0.01518, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79213, std: 0.02906, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79775, std: 0.01173, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80618, std: 0.02109, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80478, std: 0.02630, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.82163, std: 0.00534, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.81180, std: 0.02252, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.79775, std: 0.00870, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.82303, std: 0.01798, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80899, std: 0.01351, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80478, std: 0.02563, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79916, std: 0.00776, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79916, std: 0.02665, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80056, std: 0.01289, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79635, std: 0.01949, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79916, std: 0.02547, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.81601, std: 0.00955, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.81320, std: 0.01023, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.81320, std: 0.01881, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80337, std: 0.01353, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.78652, std: 0.01582, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80899, std: 0.01617, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80618, std: 0.01878, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79494, std: 0.02758, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.81742, std: 0.01729, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80337, std: 0.03928, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80197, std: 0.00870, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80618, std: 0.02109, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.81601, std: 0.02590, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.81320, std: 0.01046, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80899, std: 0.01657, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80197, std: 0.02051, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79213, std: 0.02009, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80618, std: 0.00886, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80478, std: 0.01280, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79635, std: 0.01655, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80899, std: 0.00707, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.81461, std: 0.02947, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80197, std: 0.00899, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80899, std: 0.00815, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80758, std: 0.01992, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.81039, std: 0.00557, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80337, std: 0.02276, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.81039, std: 0.01460, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80478, std: 0.00755, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80618, std: 0.01233, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79635, std: 0.02882, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79213, std: 0.01730, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80056, std: 0.01699, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79073, std: 0.01351, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79213, std: 0.02740, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80337, std: 0.00834, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.79916, std: 0.01175, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79775, std: 0.00310, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80618, std: 0.01233, params: {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.77388, std: 0.01248, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.78792, std: 0.02954, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79635, std: 0.01557, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79073, std: 0.00833, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79916, std: 0.00729, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79213, std: 0.00688, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.78933, std: 0.00884, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79494, std: 0.01012, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80337, std: 0.00562, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.81742, std: 0.01046, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.81039, std: 0.01064, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80056, std: 0.01949, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79354, std: 0.02106, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80899, std: 0.01701, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80478, std: 0.01929, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80197, std: 0.02756, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80197, std: 0.00039, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.81039, std: 0.01203, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79916, std: 0.02250, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.81039, std: 0.01034, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80197, std: 0.00556, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.77949, std: 0.01696, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.81601, std: 0.01588, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80337, std: 0.01406, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80056, std: 0.00556, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80899, std: 0.00830, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80337, std: 0.02251, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80478, std: 0.00380, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.79213, std: 0.02509, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80478, std: 0.00830, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80056, std: 0.02032, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.79635, std: 0.00974, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.81601, std: 0.00680, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.78371, std: 0.01019, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.81461, std: 0.00615, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.78792, std: 0.00223, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79354, std: 0.01149, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.81742, std: 0.01395, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80337, std: 0.02036, params: {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
# ...
#  mean: 0.81742, std: 0.00757, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.81320, std: 0.01046, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.79775, std: 0.00885, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.81320, std: 0.01281, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.81742, std: 0.01659, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.78230, std: 0.01641, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.81742, std: 0.00708, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80899, std: 0.02064, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79916, std: 0.02098, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.81320, std: 0.01930, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79916, std: 0.01683, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80337, std: 0.01060, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80478, std: 0.01656, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.81742, std: 0.01861, params: {'criterion': 'gini', 'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.76264, std: 0.02817, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.77528, std: 0.00154, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79073, std: 0.01641, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.77809, std: 0.00421, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.81039, std: 0.01523, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.78090, std: 0.00866, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.78933, std: 0.00868, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.81180, std: 0.00679, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.81039, std: 0.00655, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80758, std: 0.01083, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80899, std: 0.01067, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.81039, std: 0.00872, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80899, std: 0.00975, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80197, std: 0.00925, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80478, std: 0.01280, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.78652, std: 0.03400, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.81320, std: 0.01517, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.81601, std: 0.01178, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80056, std: 0.01557, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80056, std: 0.01387, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79916, std: 0.01759, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80337, std: 0.00834, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.81601, std: 0.00955, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79916, std: 0.00496, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80337, std: 0.00729, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80056, std: 0.01087, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.79775, std: 0.01252, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'log2', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.77809, std: 0.00353, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80197, std: 0.00347, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79494, std: 0.00951, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.76826, std: 0.01254, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.78511, std: 0.01953, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.77669, std: 0.00953, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.77107, std: 0.01346, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80478, std: 0.00707, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.81461, std: 0.01610, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79073, std: 0.01970, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80197, std: 0.01912, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.82303, std: 0.01273, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.77388, std: 0.01256, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.81320, std: 0.01174, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79354, std: 0.01769, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80478, std: 0.01571, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79635, std: 0.03068, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80197, std: 0.02440, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79494, std: 0.01674, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80337, std: 0.02143, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80478, std: 0.01393, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.79073, std: 0.01516, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80758, std: 0.01854, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79635, std: 0.00828, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.78371, std: 0.02451, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.81180, std: 0.01676, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.78652, std: 0.02545, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.79073, std: 0.00240, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.77949, std: 0.02932, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.79635, std: 0.01627, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.77669, std: 0.01837, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.78933, std: 0.00926, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79635, std: 0.00755, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.77247, std: 0.00306, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.79354, std: 0.01034, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.78933, std: 0.01535, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.80758, std: 0.01014, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.81882, std: 0.02398, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.80478, std: 0.02188, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.81320, std: 0.01068, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.81882, std: 0.02719, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.80899, std: 0.01173, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.78230, std: 0.02437, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80478, std: 0.03098, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.80478, std: 0.01393, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 9},
#  mean: 0.82022, std: 0.00681, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 4},
#  mean: 0.80618, std: 0.01202, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 6},
#  mean: 0.81461, std: 0.01461, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 9},
#  mean: 0.80337, std: 0.01518, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 4},
#  mean: 0.80337, std: 0.01992, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 6},
#  mean: 0.79354, std: 0.01485, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 9},
#  mean: 0.80478, std: 0.01929, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 4},
#  mean: 0.80758, std: 0.00777, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 6},
#  mean: 0.81882, std: 0.01749, params: {'criterion': 'gini', 'max_depth': 15, 'max_features': 'auto', 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 9}]

# %%
clf.best_score_
# Out:
# 0.827247191011236

# %%
clf.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 15,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 5,
#  'min_samples_split': 3,
#  'n_estimators': 9}

# %% [markdown]
# ## 検証
# - 検証は何か
# - なぜ検証を行う必要があるのか（Accuracyだけではダメな理由も含めること）
# - 主な検証方法について2つ以上記述せよ

# %% [markdown]
# 検証とは、**モデルの汎用性チェック**のことである。
# いくらモデルのAccuracyが高くても、それは取得データ内での正解率であり、
# 限られたデータ以外でも、正常に正解を出力できるか確認しなければならない。
#
# 主な検証方法として、下記が挙げられる。
# - ホールドアウト法
# - K-分割交差検証

# %% [markdown]
# ## KFoldについて
# 今回はKFold(K-分割交差検証)を使用して、検証を行います。
#
# - K-分割交差検証について説明せよ
# - K-分割交差検証はデータセットを何個に分割するか
# - データセットを分割する際、その個数はどのように考えると良いか
# - K-分割交差検証は何回の検証を行うか
# - K-分割交差検証の結果は、最終的にどのように求められるか

# %% [markdown]
# ## KFold実施
# Kfoldの結果(Mean Accuracy)が75%以上になっていれば成功です。
# そうでなければ、再度モデルのチューニングを行いましょう。

# %%
#X_test=X_test.reset_index().drop("index", axis=1)

# %%
from sklearn import model_selection
from sklearn.metrics import mean_squared_error

n_fold = 5 # 交差検定の回数
k_fold = model_selection.KFold(n_splits = n_fold)

# aaa=X_test.reset_index().drop("index", axis=1)

accuracy_score_list=[]
X_array=X.values
y_array=y.values
for train, test in k_fold.split(X_array):
    pred = clf.predict(X_array[test])
    accuracy_score_list.append(accuracy_score(y_array[test], pred))
    
print('Mean：' + str(np.mean(accuracy_score_list)))
print('Standard：' + str(np.std(accuracy_score_list)))
# Out:
# Mean：0.8551817211725566
# Standard：0.021036468144138603

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8044692737430168

# %% [markdown]
# ## どの特徴量が重要であったかを調査する
# sklearnでランダムフォレストを実装すると用意にどのどの特徴量が重要であったかを判明させることができます。
# feature_importances_メソッドを使用して、判明させましょう。

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(
    criterion='entropy', 
    max_depth=15, 
    max_features='sqrt', 
    min_samples_leaf=5, 
    min_samples_split=3, 
    n_estimators=9, 
    random_state=0
)
clf.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
#             max_depth=15, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=5,
#             min_samples_split=3, min_weight_fraction_leaf=0.0,
#             n_estimators=9, n_jobs=1, oob_score=False, random_state=0,
#             verbose=0, warm_start=False)

# %%
# 個々の特徴量がどの程度重要かを示す割合
clf.feature_importances_
# Out:
# array([0.08549931, 0.34743698, 0.06857767, 0.05848   , 0.024868  ,
#        0.06127156, 0.08812736, 0.15040355, 0.11533556])

# %%
data = pd.Series(clf.feature_importances_, index=list(X.columns[:9]))
data.plot(kind='bar')

# %% [markdown]
# # 線形回帰アルゴリズム

# %% [markdown]
# ## 機械学習について

# %% [markdown]
# ### 教師あり学習
# 教師あり学習とは、正解が分かっているデータをプログラムに学習させることで、正解が分からない同様のデータから正解を算出する手法。
# データから正解を分類する分類問題と、数値を予想する回帰問題の大きく２つに分けられる。
# それぞれの具体例として、
#
# 分類問題：犬の画像データから、犬種を特定
# 回帰問題：過去の電力使用に関連するデータから、未来の電力需要を予測

# %% [markdown]
# ### 教師なし学習
# 教師なし学習とは、複数のデータから相違や傾向を見つけ、無理のない最適なグループに分類する手法。
# データにどのような特徴があるのか、どのような性質のグループ分けが可能なのかを把握することが目的なので、
# 事前に正解が分かっている、上記分類問題と異なる。
# 具体例として、
#
# - 購買記録から顧客を分類し、販売戦略を考える
# - アンケートなどの文章を分類し、どういった内容のものがあるか見る
# - 不良品を分類し、工程の管理方法を考える

# %% [markdown]
# ### 半教師あり学習
# 正解が分かっているデータの数が少ない場合、正解が分かってない同様の多くのデータで補完することで、予測したり、分類したりする手法。
# 具体例として、
#
# 正解が分かっている犬猫の写真データ（数が少ない）と正解が分かっていない同様の写真データ（数が多い）で、犬と猫の写真を分類

# %% [markdown]
# ### 強化学習
#
# 人の期待に応えるようプログラムを調整して、期待に応じた行動をさせる手法。
# 具体例として、
#
# - 歩行ロボットの姿勢制御
# - 碁や将棋などの対局

# %% [markdown]
# ## データ・セットの用意
# データセット：House Prices: Advanced Regression Techniques
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# 目的変数としてSalePrice、説明変数として、GrLivAreaとYearBuiltを使用

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from IPython.display import display

df = pd.read_csv('input/train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0      2   2008        WD         Normal     208500
# 1      5   2007        WD         Normal     181500
# 2      9   2008        WD         Normal     223500
# 3      2   2006        WD        Abnorml     140000
# 4     12   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# 説明変数
X=df[['GrLivArea','YearBuilt']]
# 目的変数
y=df[['SalePrice']]

# %% [markdown]
# ## プロット
# ### GrLivArea と SalePrice の散布図

# %%
plt.scatter(X["GrLivArea"],y['SalePrice'])
plt.xlabel("GrLivArea")
plt.ylabel("SalePrice")
plt.show()

# %% [markdown]
# ### GrLivArea と YearBuilt の散布図

# %%
plt.scatter(X["YearBuilt"],y["SalePrice"])
plt.xlabel("YearBuilt")
plt.ylabel("SalePrice")
plt.show()

# %% [markdown]
# ともに正の相関が見受けられる。

# %% [markdown]
# ## フィーチャースケーリング

# %% [markdown]
# ### １）正規化とは
# 複数の数値データを数的関係を保持しながら集約し、利用しやすくすること。
# 主に [ 0, 1 ] か[ -1, 1 ] の範囲内におさめることが多い。

# %% [markdown]
# #### 例：あるクラスの数学と英語のテスト結果表
# 生徒はA〜Eの５名で、数学は２００点満点、英語は１００点満点

# %%
test=pd.DataFrame({"A":[90,70],"B":[170,80], "C":[110,60], "D":[100,90], "E":[130,80]}, index=["数学", "英語"]).T
test
# Out:
#     数学  英語
# A   90  70
# B  170  80
# C  110  60
# D  100  90
# E  130  80

# %% [markdown]
# - 各教科ごとに、各生徒を比較評価できる
# - 教科を跨いでの比較評価が難しい
#
# 0〜1の範囲で正規化をすると、

# %%
test_norm = (test-test.min()) / (test.max()-test.min())
test_norm = round(test_norm, 2)
test_norm
# Out:
#      数学    英語
# A  0.00  0.33
# B  1.00  0.67
# C  0.25  0.00
# D  0.12  1.00
# E  0.50  0.67

# %% [markdown]
# 各教科ごとに、各生徒を比較評価しつつ（互いの数的関係を維持しつつ）、教科を跨いでの比較評価も可能
#
# #### 疑問
# 数学0と英語0、数学1と英語１の評価が同じでいいのか。
# 大きく外れた点数（最大点、最小点）をとっても、値が変わらない。

# %% [markdown]
# ### ２）標準化とは
# 正規化と同様、複数の数値データを数的関係を保持しながら集約し、利用しやすくすること。
# ただ集約のルールが異なり、平均を0、標準偏差を1になるように集約させる。

# %%
test_std = (test-test.mean()) / test.std()
test_std = round(test_std, 2)
test_std
# Out:
#      数学    英語
# A -0.95 -0.53
# B  1.58  0.35
# C -0.32 -1.40
# D -0.63  1.23
# E  0.32  0.35

# %% [markdown]
# 各教科ごとに、各生徒を比較評価しつつ（互いの数的関係を維持しつつ）、教科を跨いで、すべての生徒の比較評価が可能
# 各クラスのごとの得意不得意教科も判断できる

# %% [markdown]
# ### ３）正規化、標準化の違い

# %% [markdown]
# 上記例からもわかるように、標準化の場合、大きく外れた数値（外れ値）に対しても、比較評価ができる。

# %% [markdown]
# ### ４）フィーチャースケーリングのメリット

# %% [markdown]
# 各数値データの尺度が統一されることで、数値データを跨いで、比較評価することができるようになる。
# また各特徴量のスケールを同じ範囲にすることで、より少ない学習回数で収束することができる。

# %% [markdown]
# ### SalePrice を標準化

# %%
y = (y - y.mean()) / y.std()
y.head()
# Out:
#    SalePrice
# 0   0.347154
# 1   0.007286
# 2   0.535970
# 3  -0.515105
# 4   0.869545

# %% [markdown]
# ### GrLivArea ,YearBuilt を標準化

# %%
X = (X - X.mean()) / X.std()
X.head()
# Out:
#    GrLivArea  YearBuilt
# 0   0.370207   1.050634
# 1  -0.482347   0.156680
# 2   0.514836   0.984415
# 3   0.383528  -1.862993
# 4   1.298881   0.951306

# %% [markdown]
# # 数式の実装

# %% [markdown]
# 線形回帰における目的関数（コスト関数）を実装

# %% [markdown]
# $h_\theta(x) =  \theta_0 x_0 + \theta_1 x_1 + ... +\theta_n x_n   (x_0 = 1)$
#
# $J(\theta)=  \frac{1 }{ 2m}  \sum_{i=1}^{m} (h_\theta(x^{(i)})-y^{(i)})^2$

# %%
# 各データに特徴量の値が１になる列を追記（切片、定数項）
X["x0"]=1
X.head()
# Out:
#    GrLivArea  YearBuilt  x0
# 0   0.370207   1.050634   1
# 1  -0.482347   0.156680   1
# 2   0.514836   0.984415   1
# 3   0.383528  -1.862993   1
# 4   1.298881   0.951306   1

# %%
# ３つの特徴量の係数θ（ランダム）を作成
np.random.seed(0)
theta=pd.DataFrame(np.random.rand(3))
theta
# Out:
#           0
# 0  0.548814
# 1  0.715189
# 2  0.602763

# %%
# 総データ数
m = len(X)

def compute_cost(X, y, theta):
    h = np.dot(X, theta)
    J = np.sum((h - y)**2)/(2*m)
    return J

compute_cost(X, y, theta)
# Out:
# SalePrice    0.403095
# dtype: float64

# %% [markdown]
# ### $\theta_0$ の役割
# 線形回帰モデルは、以下のように $\theta_0$ つまり、切片が存在する。
#
# $h_\theta(x) =  \theta_0 x_0 + \theta_1 x_1 + ... +\theta_n x_n   (x_0 = 1)$
#
# この $\theta_0$ の役割として、説明変数すべての値が０のとき、目的変数が０になるかわからないデータセットの場合、切片を０にしてしまうと、それが縛りとなり、モデルの表現力を下げることになる。

# %% [markdown]
# ## 最急降下法（勾配降下法、GradientDescent）

# %% [markdown]
# $\theta_j := \theta_j - \alpha \frac{1}{m} \sum_{i=1}^{m}[(h_\theta(x^{(i)}) - y^{(i)} )x_{j}^{(i)}]$

# %%
def gradient_descent(X, y, theta, iterations, alpha):
    
    # alpha： ステップ幅（学習率）
    # iterations： 反復回数
    
    m = len(X)
    past_costs = []
    past_thetas = []

    for i in range(iterations):
        past_costs.append(compute_cost(X, y, theta))
        past_thetas.append(theta)
        h = np.dot(X, theta)
        theta = theta - (alpha/m) * np.dot(X.T, h - y)
    return past_costs

# %% [markdown]
# ## 線形回帰における最急降下法の導出式
# 以下の式から、
#
# $\theta_j := \theta_j - \frac{\partial}{\partial \theta_j}J(\theta) $
#
# この式が得られるまでを導出すれば良い
#
# $\theta_j := \theta_j  −α\frac{1}{m}\sum_{i=1}^{m}((h_θ(x_i)−y_i)x_j)$
#
# 但し、 $i\neq0$ である。

# %% [markdown]
#  $v = h_θ(x)$ とする。
#
# $ \frac{\partial}{\partial \theta_j}J(\theta) = \frac{\partial}{\partial v}J(\theta)・\frac{\partial v}{\partial \theta_j}$
#
# $ \frac{\partial}{\partial \theta_j}J(\theta) $
#
# $ = \frac{1}{2m}\sum_{i=1}^{m}\frac{\partial}{\partial v}(v−y_i)^2 $
#
# $ = \frac{1}{m}\sum_{i=1}^{m}(v−y_i)　①$
#
# $ \frac{\partial v}{\partial \theta_j}$
#
# $ = \frac{\partial}{\partial \theta_j}(\theta_0x_0 + \theta_1x_1 + ... + \theta_jx_j + ... + \theta_nx_n)$
#
# $ = x_j　②$
#
# ①②より
#
# $ \frac{\partial}{\partial \theta_j}J(\theta) $
#
# $=\frac{1}{m}\sum_{i=1}^{m}(v−y_i)x_j$
#
# $=\frac{1}{m}\sum_{i=1}^{m}(h_θ(x_i)−y_i)x_j$
#
# したがって
#
# $\theta_j := \theta_j  −α\frac{1}{m}\sum_{i=1}^{m}((h_θ(x_i)−y_i)x_j)$

# %% [markdown]
# ## 最急降下法について、なぜ局所解が得られるのか

# %% [markdown]
#  多項式回帰の場合、目的関数が$x$の3次式以上となるため、凸の数が複数になり、局所解（コストが最小にならない解）が発生し得る。
# そのため、ランダムに生成された初期値$\theta$が、グラフの局所解付近からスタートし始めたら、局所解に捕まることになる。
# 単回帰や重回帰の場合、目的関数が$x$の2次式で、凸の数がひとつしかないため、そもそも局所解が存在しない。よって、自ずと最適解が得られる。

# %% [markdown]
# ## 学習

# %% [markdown]
# ### 学習率
# 一般的には0から1の間で、学習率を選択し、0.001〜0.01あたりから始めるのが通例とされている。
# 学習率を大きめにとると、最適解を跨ぎつづけ収束しきれない。その際のパラメーターを取得しても誤差が大きいため、未学習（Underfitting）の可能性が高い。
# 学習率を小さめにとると、移動量が多くなって、パラメータの更新回数は増えるものの、最適解に収束しやすい。なので誤差が限りなく小さいパラメータを取得できるが、あくまでもトレインデータでのモデルなので、  過学習（Overfitting）していないかどうか、テストデータでの検証は必要である。

# %% [markdown]
# ### 学習曲線について
# パラメータを都度更新させ、実測値との誤差が最小の値をとる最適解に収束しているかどうかグラフで判断するときに使用。
# 曲線にブレが見られると、収束しきれていないと見ることができ、大きく上に反れていると発散しているということがが分かる。
# 逆に目視で曲線にブレが見られなければ、最適解付近に収束していると判断することができる。

# %% [markdown]
# ## 学習曲線のプロット
# past_costsを使用して、学習曲線を表示する関数を作成せよ。

# %%
# 学習率
alpha = 0.01
# 反復回数
iterations = 300
past_costs=gradient_descent(X, y, theta, iterations, alpha)

def plot_learning_curve(iterations, past_costs):
    plt.plot(range(0,iterations),past_costs)
    plt.xlabel("Iterations")
    plt.ylabel("Costs")
    plt.show()
    
plot_learning_curve(iterations, past_costs)

# %% [markdown]
# ## クラス化
# 今まで作成した関数のクラス化

# %%
class LinearModel():

    def __init__(self, X, y):
        self.X=X
        self.y=y

    # 目的関数
    def compute_cost(self, theta):
        h = np.dot(self.X, theta)
        J = np.sum((h - self.y)**2)/(2*m)
        return J 

    # 最急降下法関数
    def gradient_descent(self, theta, iterations, alpha):
        m = len(self.X)
        past_costs = []
        past_thetas = []

        for i in range(iterations):
            past_costs.append(self.compute_cost(theta))
            past_thetas.append(theta)
            h = np.dot(self.X, theta)
            theta = theta - (alpha/m) * np.dot(self.X.T, h - self.y)
        return past_costs, past_thetas

    # 学習曲線プロット関数
    def plot_learning_curve(self, iterations, past_costs):
        plt.plot(range(0,iterations),past_costs)
        plt.xlabel("Iterations")
        plt.ylabel("Costs")
        plt.show()

# %% [markdown]
# ### 上記クラス内の関数の動作確認

# %%
np.random.seed(0)
theta=pd.DataFrame(np.random.rand(3))
iterations=300
alpha=0.01

# クラスオブジェクト作成
LM = LinearModel(X, y)

# %%
# 目的関数の動作確認
LM.compute_cost(theta)
# Out:
# SalePrice    0.403095
# dtype: float64

# %%
# 最急降下法関数の動作確認
(past_costs, past_thetas) = LM.gradient_descent(theta, iterations, alpha)
display(past_costs)
display(past_thetas)
# Out:
# [SalePrice    0.403095
#  dtype: float64, SalePrice    0.398574
#  dtype: float64, SalePrice    0.394142
#  dtype: float64, SalePrice    0.389798
#  dtype: float64, SalePrice    0.385539
#  dtype: float64, SalePrice    0.381365
#  dtype: float64, SalePrice    0.377274
#  dtype: float64, SalePrice    0.373264
#  dtype: float64, SalePrice    0.369333
#  dtype: float64, SalePrice    0.36548
#  dtype: float64, SalePrice    0.361702
#  dtype: float64, SalePrice    0.358
#  dtype: float64, SalePrice    0.354371
#  dtype: float64, SalePrice    0.350814
#  dtype: float64, SalePrice    0.347327
#  dtype: float64, SalePrice    0.343908
#  dtype: float64, SalePrice    0.340558
#  dtype: float64, SalePrice    0.337273
#  dtype: float64, SalePrice    0.334054
#  dtype: float64, SalePrice    0.330898
#  dtype: float64, SalePrice    0.327804
#  dtype: float64, SalePrice    0.324772
#  dtype: float64, SalePrice    0.321799
#  dtype: float64, SalePrice    0.318885
#  dtype: float64, SalePrice    0.316029
#  dtype: float64, SalePrice    0.313229
#  dtype: float64, SalePrice    0.310484
#  dtype: float64, SalePrice    0.307793
#  dtype: float64, SalePrice    0.305155
#  dtype: float64, SalePrice    0.30257
#  dtype: float64, SalePrice    0.300035
#  dtype: float64, SalePrice    0.29755
#  dtype: float64, SalePrice    0.295114
#  dtype: float64, SalePrice    0.292727
#  dtype: float64, SalePrice    0.290386
#  dtype: float64, SalePrice    0.288091
#  dtype: float64, SalePrice    0.285842
#  dtype: float64, SalePrice    0.283637
#  dtype: float64, SalePrice    0.281475
#  dtype: float64, SalePrice    0.279356
#  dtype: float64, SalePrice    0.277279
#  dtype: float64, SalePrice    0.275242
#  dtype: float64, SalePrice    0.273246
#  dtype: float64, SalePrice    0.271289
#  dtype: float64, SalePrice    0.26937
#  dtype: float64, SalePrice    0.267489
#  dtype: float64, SalePrice    0.265645
#  dtype: float64, SalePrice    0.263837
#  dtype: float64, SalePrice    0.262065
#  dtype: float64, SalePrice    0.260328
#  dtype: float64, SalePrice    0.258625
#  dtype: float64, SalePrice    0.256955
#  dtype: float64, SalePrice    0.255318
#  dtype: float64, SalePrice    0.253713
#  dtype: float64, SalePrice    0.25214
#  dtype: float64, SalePrice    0.250597
#  dtype: float64, SalePrice    0.249085
#  dtype: float64, SalePrice    0.247603
#  dtype: float64, SalePrice    0.24615
#  dtype: float64, SalePrice    0.244725
#  dtype: float64, SalePrice    0.243328
#  dtype: float64, SalePrice    0.241959
#  dtype: float64, SalePrice    0.240616
#  dtype: float64, SalePrice    0.2393
#  dtype: float64, SalePrice    0.238009
#  dtype: float64, SalePrice    0.236744
#  dtype: float64, SalePrice    0.235504
#  dtype: float64, SalePrice    0.234288
#  dtype: float64, SalePrice    0.233095
#  dtype: float64, SalePrice    0.231927
#  dtype: float64, SalePrice    0.230781
#  dtype: float64, SalePrice    0.229657
#  dtype: float64, SalePrice    0.228556
#  dtype: float64, SalePrice    0.227476
#  dtype: float64, SalePrice    0.226417
#  dtype: float64, SalePrice    0.225379
#  dtype: float64, SalePrice    0.224361
#  dtype: float64, SalePrice    0.223363
#  dtype: float64, SalePrice    0.222385
#  dtype: float64, SalePrice    0.221425
#  dtype: float64, SalePrice    0.220485
#  dtype: float64, SalePrice    0.219563
#  dtype: float64, SalePrice    0.218659
#  dtype: float64, SalePrice    0.217772
#  dtype: float64, SalePrice    0.216903
#  dtype: float64, SalePrice    0.216051
#  dtype: float64, SalePrice    0.215216
#  dtype: float64, SalePrice    0.214397
#  dtype: float64, SalePrice    0.213593
#  dtype: float64, SalePrice    0.212806
#  dtype: float64, SalePrice    0.212034
#  dtype: float64, SalePrice    0.211277
#  dtype: float64, SalePrice    0.210535
#  dtype: float64, SalePrice    0.209807
#  dtype: float64, SalePrice    0.209093
#  dtype: float64, SalePrice    0.208394
#  dtype: float64, SalePrice    0.207708
#  dtype: float64, SalePrice    0.207035
#  dtype: float64, SalePrice    0.206376
#  dtype: float64, SalePrice    0.205729
#  dtype: float64, SalePrice    0.205095
#  dtype: float64, SalePrice    0.204473
#  dtype: float64, SalePrice    0.203864
#  dtype: float64, SalePrice    0.203266
#  dtype: float64, SalePrice    0.20268
#  dtype: float64, SalePrice    0.202105
#  dtype: float64, SalePrice    0.201542
#  dtype: float64, SalePrice    0.200989
#  dtype: float64, SalePrice    0.200447
#  dtype: float64, SalePrice    0.199916
#  dtype: float64, SalePrice    0.199395
#  dtype: float64, SalePrice    0.198884
#  dtype: float64, SalePrice    0.198384
#  dtype: float64, SalePrice    0.197893
#  dtype: float64, SalePrice    0.197411
#  dtype: float64, SalePrice    0.196939
#  dtype: float64, SalePrice    0.196476
#  dtype: float64, SalePrice    0.196022
#  dtype: float64, SalePrice    0.195577
#  dtype: float64, SalePrice    0.19514
#  dtype: float64, SalePrice    0.194712
#  dtype: float64, SalePrice    0.194292
#  dtype: float64, SalePrice    0.193881
#  dtype: float64, SalePrice    0.193477
#  dtype: float64, SalePrice    0.193081
#  dtype: float64, SalePrice    0.192693
#  dtype: float64, SalePrice    0.192313
#  dtype: float64, SalePrice    0.19194
#  dtype: float64, SalePrice    0.191574
#  dtype: float64, SalePrice    0.191215
#  dtype: float64, SalePrice    0.190863
#  dtype: float64, SalePrice    0.190518
#  dtype: float64, SalePrice    0.190179
#  dtype: float64, SalePrice    0.189848
#  dtype: float64, SalePrice    0.189522
#  dtype: float64, SalePrice    0.189203
#  dtype: float64, SalePrice    0.18889
#  dtype: float64, SalePrice    0.188583
#  dtype: float64, SalePrice    0.188282
#  dtype: float64, SalePrice    0.187987
#  dtype: float64, SalePrice    0.187698
#  dtype: float64, SalePrice    0.187414
#  dtype: float64, SalePrice    0.187136
#  dtype: float64, SalePrice    0.186863
#  dtype: float64, SalePrice    0.186595
#  dtype: float64, SalePrice    0.186333
#  dtype: float64, SalePrice    0.186076
#  dtype: float64, SalePrice    0.185823
#  dtype: float64, SalePrice    0.185576
#  dtype: float64, SalePrice    0.185333
#  dtype: float64, SalePrice    0.185095
#  dtype: float64, SalePrice    0.184861
#  dtype: float64, SalePrice    0.184632
#  dtype: float64, SalePrice    0.184408
#  dtype: float64, SalePrice    0.184188
#  dtype: float64, SalePrice    0.183972
#  dtype: float64, SalePrice    0.18376
#  dtype: float64, SalePrice    0.183552
#  dtype: float64, SalePrice    0.183349
#  dtype: float64, SalePrice    0.183149
#  dtype: float64, SalePrice    0.182953
#  dtype: float64, SalePrice    0.182761
#  dtype: float64, SalePrice    0.182572
#  dtype: float64, SalePrice    0.182388
#  dtype: float64, SalePrice    0.182206
#  dtype: float64, SalePrice    0.182029
#  dtype: float64, SalePrice    0.181854
#  dtype: float64, SalePrice    0.181683
#  dtype: float64, SalePrice    0.181516
#  dtype: float64, SalePrice    0.181351
#  dtype: float64, SalePrice    0.18119
#  dtype: float64, SalePrice    0.181032
#  dtype: float64, SalePrice    0.180877
#  dtype: float64, SalePrice    0.180725
#  dtype: float64, SalePrice    0.180575
#  dtype: float64, SalePrice    0.180429
#  dtype: float64, SalePrice    0.180286
#  dtype: float64, SalePrice    0.180145
#  dtype: float64, SalePrice    0.180007
#  dtype: float64, SalePrice    0.179871
#  dtype: float64, SalePrice    0.179738
#  dtype: float64, SalePrice    0.179608
#  dtype: float64, SalePrice    0.17948
#  dtype: float64, SalePrice    0.179355
#  dtype: float64, SalePrice    0.179232
#  dtype: float64, SalePrice    0.179112
#  dtype: float64, SalePrice    0.178993
#  dtype: float64, SalePrice    0.178877
#  dtype: float64, SalePrice    0.178764
#  dtype: float64, SalePrice    0.178652
#  dtype: float64, SalePrice    0.178543
#  dtype: float64, SalePrice    0.178435
#  dtype: float64, SalePrice    0.17833
#  dtype: float64, SalePrice    0.178227
#  dtype: float64, SalePrice    0.178126
#  dtype: float64, SalePrice    0.178026
#  dtype: float64, SalePrice    0.177929
#  dtype: float64, SalePrice    0.177833
#  dtype: float64, SalePrice    0.17774
#  dtype: float64, SalePrice    0.177648
#  dtype: float64, SalePrice    0.177558
#  dtype: float64, SalePrice    0.177469
#  dtype: float64, SalePrice    0.177382
#  dtype: float64, SalePrice    0.177297
#  dtype: float64, SalePrice    0.177214
#  dtype: float64, SalePrice    0.177132
#  dtype: float64, SalePrice    0.177052
#  dtype: float64, SalePrice    0.176973
#  dtype: float64, SalePrice    0.176896
#  dtype: float64, SalePrice    0.17682
#  dtype: float64, SalePrice    0.176745
#  dtype: float64, SalePrice    0.176673
#  dtype: float64, SalePrice    0.176601
#  dtype: float64, SalePrice    0.176531
#  dtype: float64, SalePrice    0.176462
#  dtype: float64, SalePrice    0.176395
#  dtype: float64, SalePrice    0.176328
#  dtype: float64, SalePrice    0.176263
#  dtype: float64, SalePrice    0.1762
#  dtype: float64, SalePrice    0.176137
#  dtype: float64, SalePrice    0.176076
#  dtype: float64, SalePrice    0.176016
#  dtype: float64, SalePrice    0.175957
#  dtype: float64, SalePrice    0.175899
#  dtype: float64, SalePrice    0.175842
#  dtype: float64, SalePrice    0.175786
#  dtype: float64, SalePrice    0.175732
#  dtype: float64, SalePrice    0.175678
#  dtype: float64, SalePrice    0.175626
#  dtype: float64, SalePrice    0.175574
#  dtype: float64, SalePrice    0.175523
#  dtype: float64, SalePrice    0.175474
#  dtype: float64, SalePrice    0.175425
#  dtype: float64, SalePrice    0.175377
#  dtype: float64, SalePrice    0.175331
#  dtype: float64, SalePrice    0.175285
#  dtype: float64, SalePrice    0.17524
#  dtype: float64, SalePrice    0.175195
#  dtype: float64, SalePrice    0.175152
#  dtype: float64, SalePrice    0.175109
#  dtype: float64, SalePrice    0.175068
#  dtype: float64, SalePrice    0.175027
#  dtype: float64, SalePrice    0.174986
#  dtype: float64, SalePrice    0.174947
#  dtype: float64, SalePrice    0.174908
#  dtype: float64, SalePrice    0.17487
#  dtype: float64, SalePrice    0.174833
#  dtype: float64, SalePrice    0.174797
#  dtype: float64, SalePrice    0.174761
#  dtype: float64, SalePrice    0.174726
#  dtype: float64, SalePrice    0.174691
#  dtype: float64, SalePrice    0.174657
#  dtype: float64, SalePrice    0.174624
#  dtype: float64, SalePrice    0.174592
#  dtype: float64, SalePrice    0.17456
#  dtype: float64, SalePrice    0.174528
#  dtype: float64, SalePrice    0.174498
#  dtype: float64, SalePrice    0.174468
#  dtype: float64, SalePrice    0.174438
#  dtype: float64, SalePrice    0.174409
#  dtype: float64, SalePrice    0.174381
#  dtype: float64, SalePrice    0.174353
#  dtype: float64, SalePrice    0.174325
#  dtype: float64, SalePrice    0.174298
#  dtype: float64, SalePrice    0.174272
#  dtype: float64, SalePrice    0.174246
#  dtype: float64, SalePrice    0.174221
#  dtype: float64, SalePrice    0.174196
#  dtype: float64, SalePrice    0.174171
#  dtype: float64, SalePrice    0.174147
#  dtype: float64, SalePrice    0.174124
#  dtype: float64, SalePrice    0.174101
#  dtype: float64, SalePrice    0.174078
#  dtype: float64, SalePrice    0.174056
#  dtype: float64, SalePrice    0.174034
#  dtype: float64, SalePrice    0.174013
#  dtype: float64, SalePrice    0.173992
#  dtype: float64, SalePrice    0.173971
#  dtype: float64, SalePrice    0.173951
#  dtype: float64, SalePrice    0.173931
#  dtype: float64, SalePrice    0.173912
#  dtype: float64, SalePrice    0.173892
#  dtype: float64, SalePrice    0.173874
#  dtype: float64, SalePrice    0.173855
#  dtype: float64, SalePrice    0.173837
#  dtype: float64, SalePrice    0.17382
#  dtype: float64, SalePrice    0.173802
#  dtype: float64, SalePrice    0.173785
#  dtype: float64, SalePrice    0.173769
#  dtype: float64, SalePrice    0.173752
#  dtype: float64, SalePrice    0.173736
#  dtype: float64, SalePrice    0.17372
#  dtype: float64, SalePrice    0.173705
#  dtype: float64, SalePrice    0.17369
#  dtype: float64, SalePrice    0.173675
#  dtype: float64, SalePrice    0.17366
#  dtype: float64, SalePrice    0.173646
#  dtype: float64, SalePrice    0.173632
#  dtype: float64, SalePrice    0.173618
#  dtype: float64, SalePrice    0.173604
#  dtype: float64]
# [          0
#  0  0.548814
#  1  0.715189
#  2  0.602763,           0
#  0  0.548988
#  1  0.712176
#  2  0.596736,           0
#  0  0.549167
#  1  0.709193
#  2  0.590768,           0
#  0  0.549350
#  1  0.706239
#  2  0.584861,           0
#  0  0.549537
#  1  0.703315
#  2  0.579012,           0
#  0  0.549728
#  1  0.700419
#  2  0.573222,           0
#  0  0.549923
#  1  0.697551
#  2  0.567490,           0
#  0  0.550122
#  1  0.694712
#  2  0.561815,           0
#  0  0.550324
#  1  0.691901
#  2  0.556197,           0
#  0  0.550530
#  1  0.689118
#  2  0.550635,           0
#  0  0.550740
#  1  0.686362
#  2  0.545128,           0
#  0  0.550952
#  1  0.683633
#  2  0.539677,           0
#  0  0.551169
#  1  0.680931
#  2  0.534280,           0
#  0  0.551388
#  1  0.678256
#  2  0.528938,           0
#  0  0.551610
#  1  0.675607
#  2  0.523648,           0
#  0  0.551836
#  1  0.672984
#  2  0.518412,           0
#  0  0.552064
#  1  0.670387
#  2  0.513228,           0
#  0  0.552295
#  1  0.667815
#  2  0.508095,           0
#  0  0.552530
#  1  0.665268
#  2  0.503014,           0
#  0  0.552766
#  1  0.662747
#  2  0.497984,           0
#  0  0.553006
#  1  0.660250
#  2  0.493004,           0
#  0  0.553248
#  1  0.657777
#  2  0.488074,           0
#  0  0.553492
#  1  0.655329
#  2  0.483194,           0
#  0  0.553739
#  1  0.652905
#  2  0.478362,           0
#  0  0.553989
#  1  0.650505
#  2  0.473578,           0
#  0  0.554240
#  1  0.648128
#  2  0.468842,           0
#  0  0.554494
#  1  0.645774
#  2  0.464154,           0
#  0  0.554750
#  1  0.643443
#  2  0.459512,           0
#  0  0.555008
#  1  0.641136
#  2  0.454917,           0
#  0  0.555268
#  1  0.638850
#  2  0.450368,           0
#  0  0.555530
#  1  0.636587
#  2  0.445864,           0
#  0  0.555794
#  1  0.634346
#  2  0.441406,           0
#  0  0.556060
#  1  0.632127
#  2  0.436992,           0
#  0  0.556327
#  1  0.629930
#  2  0.432622,           0
#  0  0.556597
#  1  0.627754
#  2  0.428295,           0
#  0  0.556867
#  1  0.625599
#  2  0.424013,           0
#  0  0.557140
#  1  0.623465
#  2  0.419772,           0
#  0  0.557414
#  1  0.621352
#  2  0.415575,           0
#  0  0.557689
#  1  0.619260
#  2  0.411419,           0
#  0  0.557966
#  1  0.617188
#  2  0.407305,           0
#  0  0.558244
#  1  0.615136
#  2  0.403232,           0
#  0  0.558523
#  1  0.613104
#  2  0.399199,           0
#  0  0.558804
#  1  0.611092
#  2  0.395207,           0
#  0  0.559086
#  1  0.609099
#  2  0.391255,           0
#  0  0.559369
#  1  0.607126
#  2  0.387343,           0
#  0  0.559653
#  1  0.605172
#  2  0.383469,           0
#  0  0.559938
#  1  0.603236
#  2  0.379635,           0
#  0  0.560224
#  1  0.601320
#  2  0.375838,           0
#  0  0.560512
#  1  0.599422
#  2  0.372080,           0
#  0  0.560800
#  1  0.597543
#  2  0.368359,           0
#  0  0.561088
#  1  0.595682
#  2  0.364675,           0
#  0  0.561378
#  1  0.593838
#  2  0.361029,           0
#  0  0.561669
#  1  0.592013
#  2  0.357418,           0
#  0  0.561960
#  1  0.590205
#  2  0.353844,           0
#  0  0.562252
#  1  0.588415
#  2  0.350306,           0
#  0  0.562544
#  1  0.586642
#  2  0.346803,           0
#  0  0.562837
#  1  0.584886
#  2  0.343335,           0
#  0  0.563131
#  1  0.583148
#  2  0.339901,           0
#  0  0.563425
#  1  0.581426
#  2  0.336502,           0
#  0  0.563720
#  1  0.579720
#  2  0.333137,           0
#  0  0.564015
#  1  0.578031
#  2  0.329806,           0
#  0  0.564311
#  1  0.576359
#  2  0.326508,           0
#  0  0.564607
#  1  0.574702
#  2  0.323243,           0
#  0  0.564903
#  1  0.573062
#  2  0.320010,           0
#  0  0.565199
#  1  0.571437
#  2  0.316810,           0
#  0  0.565496
#  1  0.569828
#  2  0.313642,           0
#  0  0.565793
#  1  0.568234
#  2  0.310506,           0
#  0  0.566091
#  1  0.566656
#  2  0.307401,           0
#  0  0.566388
#  1  0.565093
#  2  0.304327,           0
#  0  0.566686
#  1  0.563545
#  2  0.301283,           0
#  0  0.566983
#  1  0.562012
#  2  0.298271,           0
#  0  0.567281
#  1  0.560493
#  2  0.295288,           0
#  0  0.567579
#  1  0.558989
#  2  0.292335,           0
#  0  0.567877
#  1  0.557500
#  2  0.289412,           0
#  0  0.568174
#  1  0.556025
#  2  0.286518,           0
#  0  0.568472
#  1  0.554564
#  2  0.283652,           0
#  0  0.568770
#  1  0.553117
#  2  0.280816,           0
#  0  0.569067
#  1  0.551684
#  2  0.278008,           0
#  0  0.569365
#  1  0.550264
#  2  0.275228,           0
#  0  0.569662
#  1  0.548858
#  2  0.272475,           0
#  0  0.569959
#  1  0.547466
#  2  0.269751,           0
#  0  0.570256
#  1  0.546087
#  2  0.267053,           0
#  0  0.570553
#  1  0.544721
#  2  0.264383,           0
#  0  0.570849
#  1  0.543368
#  2  0.261739,           0
#  0  0.571146
#  1  0.542029
#  2  0.259121,           0
#  0  0.571442
#  1  0.540702
#  2  0.256530,           0
#  0  0.571737
#  1  0.539387
#  2  0.253965,           0
#  0  0.572032
#  1  0.538085
#  2  0.251425,           0
#  0  0.572327
#  1  0.536796
#  2  0.248911,           0
#  0  0.572622
#  1  0.535519
#  2  0.246422,           0
#  0  0.572916
#  1  0.534254
#  2  0.243958,           0
#  0  0.573209
#  1  0.533001
#  2  0.241518,           0
#  0  0.573503
#  1  0.531760
#  2  0.239103,           0
#  0  0.573795
#  1  0.530531
#  2  0.236712,           0
#  0  0.574088
#  1  0.529314
#  2  0.234345,           0
#  0  0.574380
#  1  0.528108
#  2  0.232001,           0
#  0  0.574671
#  1  0.526913
#  2  0.229681,           0
#  0  0.574962
#  1  0.525730
#  2  0.227384,           0
#  0  0.575252
#  1  0.524559
#  2  0.225111,           0
#  0  0.575541
#  1  0.523398
#  2  0.222859,           0
#  0  0.575830
#  1  0.522249
#  2  0.220631,           0
#  0  0.576119
#  1  0.521110
#  2  0.218425,           0
#  0  0.576407
#  1  0.519982
#  2  0.216240,           0
#  0  0.576694
#  1  0.518865
#  2  0.214078,           0
#  0  0.576980
#  1  0.517758
#  2  0.211937,           0
#  0  0.577266
#  1  0.516662
#  2  0.209818,           0
#  0  0.577551
#  1  0.515576
#  2  0.207720,           0
#  0  0.577836
#  1  0.514501
#  2  0.205642,           0
#  0  0.578120
#  1  0.513436
#  2  0.203586,           0
#  0  0.578403
#  1  0.512380
#  2  0.201550,           0
#  0  0.578685
#  1  0.511335
#  2  0.199535,           0
#  0  0.578967
#  1  0.510300
#  2  0.197539,           0
#  0  0.579247
#  1  0.509274
#  2  0.195564,           0
#  0  0.579527
#  1  0.508259
#  2  0.193608,           0
#  0  0.579807
#  1  0.507252
#  2  0.191672,           0
#  0  0.580085
#  1  0.506256
#  2  0.189755,           0
#  0  0.580363
#  1  0.505268
#  2  0.187858,           0
#  0  0.580640
#  1  0.504290
#  2  0.185979,           0
#  0  0.580916
#  1  0.503321
#  2  0.184120,           0
#  0  0.581191
#  1  0.502362
#  2  0.182278,           0
#  0  0.581466
#  1  0.501411
#  2  0.180456,           0
#  0  0.581739
#  1  0.500470
#  2  0.178651,           0
#  0  0.582012
#  1  0.499537
#  2  0.176864,           0
#  0  0.582284
#  1  0.498613
#  2  0.175096,           0
#  0  0.582555
#  1  0.497697
#  2  0.173345,           0
#  0  0.582825
#  1  0.496791
#  2  0.171611,           0
#  0  0.583094
#  1  0.495892
#  2  0.169895,           0
#  0  0.583362
#  1  0.495003
#  2  0.168196,           0
#  0  0.583629
#  1  0.494121
#  2  0.166514,           0
#  0  0.583896
#  1  0.493248
#  2  0.164849,           0
#  0  0.584161
#  1  0.492383
#  2  0.163201,           0
#  0  0.584426
#  1  0.491526
#  2  0.161569,           0
#  0  0.584689
#  1  0.490678
#  2  0.159953,           0
#  0  0.584952
#  1  0.489837
#  2  0.158354,           0
#  0  0.585214
#  1  0.489004
#  2  0.156770,           0
#  0  0.585475
#  1  0.488179
#  2  0.155202,           0
#  0  0.585734
#  1  0.487361
#  2  0.153650,           0
#  0  0.585993
#  1  0.486552
#  2  0.152114,           0
#  0  0.586251
#  1  0.485749
#  2  0.150593,           0
#  0  0.586508
#  1  0.484955
#  2  0.149087,           0
#  0  0.586764
#  1  0.484168
#  2  0.147596,           0
#  0  0.587019
#  1  0.483388
#  2  0.146120,           0
#  0  0.587273
#  1  0.482615
#  2  0.144659,           0
#  0  0.587525
#  1  0.481850
#  2  0.143212,           0
#  0  0.587777
#  1  0.481091
#  2  0.141780,           0
#  0  0.588028
#  1  0.480340
#  2  0.140362,           0
#  0  0.588278
#  1  0.479596
#  2  0.138959,           0
#  0  0.588527
#  1  0.478859
#  2  0.137569,           0
#  0  0.588775
#  1  0.478129
#  2  0.136193,           0
#  0  0.589022
#  1  0.477405
#  2  0.134831,           0
#  0  0.589267
#  1  0.476688
#  2  0.133483,           0
#  0  0.589512
#  1  0.475978
#  2  0.132148,           0
#  0  0.589756
#  1  0.475275
#  2  0.130827,           0
#  0  0.589999
#  1  0.474578
#  2  0.129518,           0
#  0  0.590240
#  1  0.473887
#  2  0.128223,           0
#  0  0.590481
#  1  0.473203
#  2  0.126941,           0
#  0  0.590720
#  1  0.472525
#  2  0.125672,           0
#  0  0.590959
#  1  0.471854
#  2  0.124415,           0
#  0  0.591196
#  1  0.471189
#  2  0.123171,           0
#  0  0.591433
#  1  0.470530
#  2  0.121939,           0
#  0  0.591668
#  1  0.469877
#  2  0.120720,           0
#  0  0.591902
#  1  0.469230
#  2  0.119512,           0
#  0  0.592136
#  1  0.468589
#  2  0.118317,           0
#  0  0.592368
#  1  0.467954
#  2  0.117134,           0
#  0  0.592599
#  1  0.467325
#  2  0.115963,           0
#  0  0.592829
#  1  0.466702
#  2  0.114803,           0
#  0  0.593058
#  1  0.466085
#  2  0.113655,           0
#  0  0.593286
#  1  0.465473
#  2  0.112519,           0
#  0  0.593513
#  1  0.464867
#  2  0.111393,           0
#  0  0.593739
#  1  0.464267
#  2  0.110279,           0
#  0  0.593963
#  1  0.463672
#  2  0.109177,           0
#  0  0.594187
#  1  0.463082
#  2  0.108085,           0
#  0  0.594410
#  1  0.462498
#  2  0.107004,           0
#  0  0.594631
#  1  0.461920
#  2  0.105934,           0
#  0  0.594852
#  1  0.461347
#  2  0.104875,           0
#  0  0.595071
#  1  0.460779
#  2  0.103826,           0
#  0  0.595290
#  1  0.460216
#  2  0.102788,           0
#  0  0.595507
#  1  0.459659
#  2  0.101760,           0
#  0  0.595723
#  1  0.459106
#  2  0.100742,           0
#  0  0.595939
#  1  0.458559
#  2  0.099735,           0
#  0  0.596153
#  1  0.458017
#  2  0.098737,           0
#  0  0.596366
#  1  0.457479
#  2  0.097750,           0
#  0  0.596578
#  1  0.456947
#  2  0.096773,           0
#  0  0.596789
#  1  0.456420
#  2  0.095805,           0
#  0  0.596999
#  1  0.455897
#  2  0.094847,           0
#  0  0.597207
#  1  0.455380
#  2  0.093898,           0
#  0  0.597415
#  1  0.454867
#  2  0.092959,           0
#  0  0.597622
#  1  0.454358
#  2  0.092030,           0
#  0  0.597828
#  1  0.453855
#  2  0.091109,           0
#  0  0.598032
#  1  0.453356
#  2  0.090198,           0
#  0  0.598236
#  1  0.452861
#  2  0.089296,           0
#  0  0.598438
#  1  0.452372
#  2  0.088403,           0
#  0  0.598640
#  1  0.451886
#  2  0.087519,           0
#  0  0.598840
#  1  0.451405
#  2  0.086644,           0
#  0  0.599040
#  1  0.450929
#  2  0.085778,           0
#  0  0.599238
#  1  0.450457
#  2  0.084920,           0
#  0  0.599435
#  1  0.449989
#  2  0.084071,           0
#  0  0.599631
#  1  0.449525
#  2  0.083230,           0
#  0  0.599827
#  1  0.449066
#  2  0.082398,           0
#  0  0.600021
#  1  0.448611
#  2  0.081574,           0
#  0  0.600214
#  1  0.448160
#  2  0.080758,           0
#  0  0.600406
#  1  0.447713
#  2  0.079950,           0
#  0  0.600597
#  1  0.447270
#  2  0.079151,           0
#  0  0.600787
#  1  0.446832
#  2  0.078359,           0
#  0  0.600976
#  1  0.446397
#  2  0.077576,           0
#  0  0.601164
#  1  0.445966
#  2  0.076800,           0
#  0  0.601351
#  1  0.445540
#  2  0.076032,           0
#  0  0.601537
#  1  0.445117
#  2  0.075272,           0
#  0  0.601722
#  1  0.444698
#  2  0.074519,           0
#  0  0.601906
#  1  0.444283
#  2  0.073774,           0
#  0  0.602089
#  1  0.443871
#  2  0.073036,           0
#  0  0.602271
#  1  0.443463
#  2  0.072306,           0
#  0  0.602451
#  1  0.443059
#  2  0.071583,           0
#  0  0.602631
#  1  0.442659
#  2  0.070867,           0
#  0  0.602810
#  1  0.442263
#  2  0.070158,           0
#  0  0.602988
#  1  0.441870
#  2  0.069457,           0
#  0  0.603165
#  1  0.441480
#  2  0.068762,           0
#  0  0.603341
#  1  0.441094
#  2  0.068074,           0
#  0  0.603516
#  1  0.440712
#  2  0.067394,           0
#  0  0.603690
#  1  0.440333
#  2  0.066720,           0
#  0  0.603863
#  1  0.439957
#  2  0.066053,           0
#  0  0.604034
#  1  0.439585
#  2  0.065392,           0
#  0  0.604205
#  1  0.439216
#  2  0.064738,           0
#  0  0.604375
#  1  0.438851
#  2  0.064091,           0
#  0  0.604544
#  1  0.438489
#  2  0.063450,           0
#  0  0.604713
#  1  0.438130
#  2  0.062815,           0
#  0  0.604880
#  1  0.437775
#  2  0.062187,           0
#  0  0.605046
#  1  0.437422
#  2  0.061565,           0
#  0  0.605211
#  1  0.437073
#  2  0.060950,           0
#  0  0.605375
#  1  0.436727
#  2  0.060340,           0
#  0  0.605538
#  1  0.436385
#  2  0.059737,           0
#  0  0.605701
#  1  0.436045
#  2  0.059139,           0
#  0  0.605862
#  1  0.435708
#  2  0.058548,           0
#  0  0.606022
#  1  0.435375
#  2  0.057963,           0
#  0  0.606182
#  1  0.435044
#  2  0.057383,           0
#  0  0.606340
#  1  0.434716
#  2  0.056809,           0
#  0  0.606498
#  1  0.434392
#  2  0.056241,           0
#  0  0.606655
#  1  0.434070
#  2  0.055679,           0
#  0  0.606810
#  1  0.433751
#  2  0.055122,           0
#  0  0.606965
#  1  0.433435
#  2  0.054571,           0
#  0  0.607119
#  1  0.433122
#  2  0.054025,           0
#  0  0.607272
#  1  0.432812
#  2  0.053485,           0
#  0  0.607424
#  1  0.432504
#  2  0.052950,           0
#  0  0.607575
#  1  0.432200
#  2  0.052420,           0
#  0  0.607726
#  1  0.431898
#  2  0.051896,           0
#  0  0.607875
#  1  0.431599
#  2  0.051377,           0
#  0  0.608024
#  1  0.431302
#  2  0.050863,           0
#  0  0.608171
#  1  0.431008
#  2  0.050355,           0
#  0  0.608318
#  1  0.430717
#  2  0.049851,           0
#  0  0.608464
#  1  0.430428
#  2  0.049353,           0
#  0  0.608609
#  1  0.430142
#  2  0.048859,           0
#  0  0.608753
#  1  0.429859
#  2  0.048371,           0
#  0  0.608896
#  1  0.429578
#  2  0.047887,           0
#  0  0.609038
#  1  0.429300
#  2  0.047408,           0
#  0  0.609179
#  1  0.429024
#  2  0.046934,           0
#  0  0.609320
#  1  0.428750
#  2  0.046465,           0
#  0  0.609460
#  1  0.428479
#  2  0.046000,           0
#  0  0.609598
#  1  0.428211
#  2  0.045540,           0
#  0  0.609736
#  1  0.427945
#  2  0.045084,           0
#  0  0.609874
#  1  0.427681
#  2  0.044634,           0
#  0  0.610010
#  1  0.427420
#  2  0.044187,           0
#  0  0.610145
#  1  0.427161
#  2  0.043745,           0
#  0  0.610280
#  1  0.426904
#  2  0.043308,           0
#  0  0.610414
#  1  0.426650
#  2  0.042875,           0
#  0  0.610547
#  1  0.426397
#  2  0.042446,           0
#  0  0.610679
#  1  0.426148
#  2  0.042022,           0
#  0  0.610810
#  1  0.425900
#  2  0.041601,           0
#  0  0.610941
#  1  0.425654
#  2  0.041185,           0
#  0  0.611070
#  1  0.425411
#  2  0.040774,           0
#  0  0.611199
#  1  0.425170
#  2  0.040366,           0
#  0  0.611327
#  1  0.424931
#  2  0.039962,           0
#  0  0.611454
#  1  0.424694
#  2  0.039563,           0
#  0  0.611581
#  1  0.424460
#  2  0.039167,           0
#  0  0.611706
#  1  0.424227
#  2  0.038775,           0
#  0  0.611831
#  1  0.423997
#  2  0.038388,           0
#  0  0.611955
#  1  0.423768
#  2  0.038004,           0
#  0  0.612079
#  1  0.423542
#  2  0.037624,           0
#  0  0.612201
#  1  0.423317
#  2  0.037247,           0
#  0  0.612323
#  1  0.423095
#  2  0.036875,           0
#  0  0.612444
#  1  0.422875
#  2  0.036506,           0
#  0  0.612564
#  1  0.422656
#  2  0.036141,           0
#  0  0.612683
#  1  0.422440
#  2  0.035780,           0
#  0  0.612802
#  1  0.422225
#  2  0.035422,           0
#  0  0.612920
#  1  0.422013
#  2  0.035068,           0
#  0  0.613037
#  1  0.421802
#  2  0.034717,           0
#  0  0.613153
#  1  0.421593
#  2  0.034370,           0
#  0  0.613269
#  1  0.421386
#  2  0.034026,           0
#  0  0.613384
#  1  0.421181
#  2  0.033686,           0
#  0  0.613498
#  1  0.420977
#  2  0.033349,           0
#  0  0.613611
#  1  0.420776
#  2  0.033016,           0
#  0  0.613724
#  1  0.420576
#  2  0.032685,           0
#  0  0.613836
#  1  0.420378
#  2  0.032359,           0
#  0  0.613947
#  1  0.420182
#  2  0.032035,           0
#  0  0.614058
#  1  0.419987
#  2  0.031715,           0
#  0  0.614167
#  1  0.419794
#  2  0.031397,           0
#  0  0.614276
#  1  0.419603
#  2  0.031083,           0
#  0  0.614385
#  1  0.419414
#  2  0.030773,           0
#  0  0.614492
#  1  0.419226
#  2  0.030465,           0
#  0  0.614599
#  1  0.419040
#  2  0.030160,           0
#  0  0.614706
#  1  0.418856
#  2  0.029859]

# %%
# 学習曲線プロット関数の動作確認
LM.plot_learning_curve(iterations, past_costs)

# %% [markdown]
# ## 正規方程式
# https://qiita.com/antimon2/items/ac1ebaed75ad58406b94
#
# #### 最急降下法
# シンプルな機械学習アルゴリズムのため、 特徴量が増えても遅くなりにくいが、適切な学習率を選定する必要がある。
# また、パラメーターを更新しつづけて最適解に収束させる手法なので、解を得るまで時間がかかる。
#
# #### 正規方程式
# 学習率を選定することなく解を求めることができる。
# ただし、逆行列の計算式を含むため、特徴量が多いと計算量が増え遅くなる
